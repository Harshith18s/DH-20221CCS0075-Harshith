# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
mymap=folium.Map(location=[1.366623,103.821285],width=950,height=550,zoom_start=12,tiles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa16456e7a823211c7c84ae8289749c6 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa16456e7a823211c7c84ae8289749c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa16456e7a823211c7c84ae8289749c6 = L.map(
#                 &quot;map_aa16456e7a823211c7c84ae8289749c6&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe2727fae25a5d5751a0b9af06b684a3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa16456e7a823211c7c84ae8289749c6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
mymap=folium.Map(location=[13.0354,77.5988],
                 marker=True,
                 width=1000,
                 height=600,
                 zoom_start=12,
                 tiles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0420463711b0c9f4cac3ef471ab39ad7 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0420463711b0c9f4cac3ef471ab39ad7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0420463711b0c9f4cac3ef471ab39ad7 = L.map(
#                 &quot;map_0420463711b0c9f4cac3ef471ab39ad7&quot;,
#                 {
#                     center: [13.0354, 77.5988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     marker: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b9715af6b1973d573de6d8900a8f0f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0420463711b0c9f4cac3ef471ab39ad7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
bangalore_coords = (12.9716, 77.5946)

map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)


places = {
    "Lalbagh Botanical Garden": (12.9507, 77.5844),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Kempegowda International Airport": (13.192665896, 77.703330)
}

images = {
    "Lalbagh Botanical Garden": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&h=1200&s=1",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Kempegowda International Airport": "https://tse4.mm.bing.net/th?id=OIP.tu4IQk62ZmQfQhbIPDfZ8AHaE8&pid=Api&P=0&h=180"
}

for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff04c2f4d4bb006164e23181a965268a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff04c2f4d4bb006164e23181a965268a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff04c2f4d4bb006164e23181a965268a = L.map(
#                 &quot;map_ff04c2f4d4bb006164e23181a965268a&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe42b607baf3548cb417db53e5f5e87b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#             var marker_5465a9a52a8af1a73e7d8e44d45742f2 = L.marker(
#                 [12.9507, 77.5844],
#                 {}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#         var popup_fbc58d8fd58f0d822242868b239e65fc = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a43d05a2d05f41a7898c049e24d490ce = $(`&lt;div id=&quot;html_a43d05a2d05f41a7898c049e24d490ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lalbagh Botanical Garden&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&amp;h=1200&amp;s=1&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_fbc58d8fd58f0d822242868b239e65fc.setContent(html_a43d05a2d05f41a7898c049e24d490ce);
#
#
#
#         marker_5465a9a52a8af1a73e7d8e44d45742f2.bindPopup(popup_fbc58d8fd58f0d822242868b239e65fc)
#         ;
#
#
#
#
#             var marker_4977e13ce272102f45bf709e64ef4f9a = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#         var popup_c1284e5e27d784cbb09a422ef4c49ef5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a36579f59a482552d646688893757920 = $(`&lt;div id=&quot;html_a36579f59a482552d646688893757920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_c1284e5e27d784cbb09a422ef4c49ef5.setContent(html_a36579f59a482552d646688893757920);
#
#
#
#         marker_4977e13ce272102f45bf709e64ef4f9a.bindPopup(popup_c1284e5e27d784cbb09a422ef4c49ef5)
#         ;
#
#
#
#
#             var marker_627ee8bf68f859e240a454c295e8bfef = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#         var popup_766cae5af9e899c0c2e2dd67c374eaec = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_d0cd11b98dce16f07187280a98a765de = $(`&lt;div id=&quot;html_d0cd11b98dce16f07187280a98a765de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_766cae5af9e899c0c2e2dd67c374eaec.setContent(html_d0cd11b98dce16f07187280a98a765de);
#
#
#
#         marker_627ee8bf68f859e240a454c295e8bfef.bindPopup(popup_766cae5af9e899c0c2e2dd67c374eaec)
#         ;
#
#
#
#
#             var marker_eff782dbe15a50a2e4abbc832712e37c = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#         var popup_23a9bedf45354fc78cf62ed082b313fa = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_aae5c428f2f17a1d263067f08b4d8c25 = $(`&lt;div id=&quot;html_aae5c428f2f17a1d263067f08b4d8c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vidhana Soudha&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_23a9bedf45354fc78cf62ed082b313fa.setContent(html_aae5c428f2f17a1d263067f08b4d8c25);
#
#
#
#         marker_eff782dbe15a50a2e4abbc832712e37c.bindPopup(popup_23a9bedf45354fc78cf62ed082b313fa)
#         ;
#
#
#
#
#             var marker_f7761d1ad1972462aa3f1e418d890b3f = L.marker(
#                 [13.1682, 77.5354],
#                 {}
#             ).addTo(map_ff04c2f4d4bb006164e23181a965268a);
#
#
#         var popup_f66b2b277a8eae7576a674d9d2dbe86e = L.popup({&
